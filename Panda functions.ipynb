# %% [markdown]
# ## Functions & Methods
# ### Dataframe/Series.head() method
# **Example #1**

# %%
# importing pandas module 
import pandas as pd 
  
# making data frame 
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv") 
  
# calling head() method  
# storing in new variable 
data_top = data.head() 
  
# display 
data_top
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# **Example 2**

# %%
# importing pandas module 
import pandas as pd 
  
# making data frame 
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv") 
  
# number of rows to return 
n = 9
  
# creating series 
series = data["Name"] 
  
# returning top n rows 
top = series.head(n = n) 
  
# display 
top
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# 6    Jordan Mickey
# 7     Kelly Olynyk
# 8     Terry Rozier
# Name: Name, dtype: object

# %% [markdown]
# ### Dataframe/Series.describe() method
# **Example 1**

# %%
# importing pandas module  
import pandas as pd  
  
# importing regex module 
import re 
    
# making data frame  
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")  
    
# removing null values to avoid errors  
data.dropna(inplace = True)  
  
# percentile list 
perc =[.20, .40, .60, .80] 
  
# list of dtypes to include 
include =['object', 'float', 'int'] 
  
# calling describe method 
desc = data.describe(percentiles = perc, include = include) 
  
# display 
desc
# Out:
#               Name                  Team      Number Position         Age  \
# count          364                   364  364.000000      364  364.000000
# unique         364                    30         NaN        5         NaN
# top     Jeff Green  New Orleans Pelicans         NaN       SG         NaN
# freq             1                    16         NaN       87         NaN
# mean           NaN                   NaN   16.829670      NaN   26.615385
# std            NaN                   NaN   14.994162      NaN    4.233591
# min            NaN                   NaN    0.000000      NaN   19.000000
# 20%            NaN                   NaN    4.000000      NaN   23.000000
# 40%            NaN                   NaN    9.000000      NaN   25.000000
# 50%            NaN                   NaN   12.000000      NaN   26.000000
# 60%            NaN                   NaN   17.000000      NaN   27.000000
# 80%            NaN                   NaN   30.000000      NaN   30.000000
# ...

# %% [markdown]
# **Example 2**

# %%
# importing pandas module  
import pandas as pd  
  
# importing regex module 
import re 
    
# making data frame  
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")  
    
# removing null values to avoid errors  
data.dropna(inplace = True)  
  
# calling describe method 
desc = data["Name"].describe() 
  
# display 
desc
# Out:
# count            364
# unique           364
# top       Jeff Green
# freq               1
# Name: Name, dtype: object

# %% [markdown]
# ## Dataframe/Series.loc[]method
# **Example**

# %%
# importing pandas package 
import pandas as pd 
  
# making data frame from csv file 
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv", index_col ="Name") 
  
# retrieving row by loc method 
first = data.loc["Avery Bradley"] 
second = data.loc["R.J. Hunter"] 
  
print(first, "\n\n\n", second)
# Out:
# Team        Boston Celtics
# Number                   0
# Position                PG
# Age                     25
# Height                 6-2
# Weight                 180
# College              Texas
# Salary         7.73034e+06
# Name: Avery Bradley, dtype: object
#
#
#  Team        Boston Celtics
# Number                  28
# Position                SG
# Age                     22
# Height                 6-5
# Weight                 185
# College      Georgia State
# Salary         1.14864e+06
# Name: R.J. Hunter, dtype: object

# %% [markdown]
# **Example**

# %%
# importing pandas package 
import pandas as pd 
  
# making data frame from csv file 
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv", index_col ="Name") 
  
# retrieving rows by loc method 
rows = data.loc[["Avery Bradley", "R.J. Hunter"]] 
  
# checking data type of rows 
print(type(rows)) 
  
# display 
rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#                      College     Salary
# Name
# Avery Bradley          Texas  7730337.0
# R.J. Hunter    Georgia State  1148640.0

# %% [markdown]
# ### Dataframe/Series.iloc[] method
# **Example 1**

# %%
# importing pandas package 
import pandas as pd 
  
# making data frame from csv file  
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv") 
  
# retrieving rows by loc method  
row1 = data.loc[3] 
  
# retrieving rows by iloc method 
row2 = data.iloc[3] 
  
# checking if values are equal 
row1 == row2
# Out:
# Name        True
# Team        True
# Number      True
# Position    True
# Age         True
# Height      True
# Weight      True
# College     True
# Salary      True
# Name: 3, dtype: bool

# %% [markdown]
# **Example 2**

# %%
# importing pandas package 
import pandas as pd 
  
# making data frame from csv file  
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv") 
  
# retrieving rows by loc method  
row1 = data.iloc[[4, 5, 6, 7]] 
  
# retrieving rows by loc method  
row2 = data.iloc[4:8] 
  
# comparing values 
row1 == row2
# Out:
#    Name  Team  Number  Position   Age  Height  Weight  College  Salary
# 4  True  True    True      True  True    True    True    False    True
# 5  True  True    True      True  True    True    True    False    True
# 6  True  True    True      True  True    True    True     True    True
# 7  True  True    True      True  True    True    True     True    True

# %% [markdown]
# ### Pandas.read_csv() method
# **Example 1**

# %%
# Import pandas 
import pandas as pd 
  
# reading csv file  
pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# Example 2

# %%
# importing Pandas library 
import pandas as pd 
  
pd.read_csv(filepath_or_buffer = "https://media.geeksforgeeks.org/wp-content/uploads/nba.csv") 
  
# makes the passed rows header 
pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv", header =[1, 2]) 
  
# make the passed column as index instead of 0, 1, 2, 3.... 
pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv", index_col ='Type') 
  
# uses passed cols only for data frame 
pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv", usecols =["Type"]) 
  
# reutruns pandas series if there is only one colunmn 
pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv", usecols =["Type"], squeeze = True) 
                                
# skips the passed rows in new series 
pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv", skiprows = [1, 2, 3, 4])
